# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sb

# %% [markdown]
# ### Loading Dataset

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### Basic Inspection

# %%
df.shape #(rows,columns) or no. of(observations,features)
# Out:
# (150, 6)

# %%
df.dtypes #checking for different data types
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
print(df.head()) #first 5 observations
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.tail()) #last 5 observations
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
print(df.describe())  #basic summary of data
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print(df.info()) #information about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %% [markdown]
# ### Cleaning Data

# %%
df.drop('Id',axis=1,inplace=True)
df
#dropping id as it just serial number and is of no use
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#addressing duplicates 
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
#dropping duplicate rows if any 
df.drop_duplicates()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %% [markdown]
# #### Checking missing values if any

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]>

# %%
# calculating percentage of missing data 
(df.isnull().sum()/(len(df)))*100
# Out:
# SepalLengthCm    0.0
# SepalWidthCm     0.0
# PetalLengthCm    0.0
# PetalWidthCm     0.0
# Species          0.0
# dtype: float64

# %% [markdown]
# ##### since there are no missing values we move on to the next part of our analysis

# %% [markdown]
# ### Univariate Analysis
# ##### Analyzing single variable at a time

# %%
#seperating Numerical and Categorical variables for better analysix
cat=df.select_dtypes(include=['object']).columns
num=df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables")
print(cat)
print("Numerical Variables")
print(num)
# Out:
# Categorical Variables
# Index(['Species'], dtype='object')
# Numerical Variables
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
for i in num:
    print(i)
    print('Skew :',round(df[i].skew(),2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[i].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sb.boxplot(x=df[i])
    plt.show()
# Out:
# SepalLengthCm
# Skew : 0.31
# SepalWidthCm
# Skew : 0.33
# PetalLengthCm
# Skew : -0.27
# PetalWidthCm
# Skew : -0.1

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#density plots

for i in num:
    plt.figure(figsize=(8,6))
    sb.kdeplot(df[i])
    plt.title('Density Plot for {i}')
    plt.xlabel(i)
    plt.ylabel('Density')
    plt.show()

# %%
#violin plots 
for feature in num:
    plt.figure(figsize=(8, 6))
    sb.violinplot(x='Species', y=feature, data=df)
    plt.title(f'Violin Plot of {feature} by Species')
    plt.show()

# %%
# Swarm Plots
for feature in num:
    plt.figure(figsize=(8, 6))
    sb.swarmplot(x='Species', y=feature, data=df)
    plt.title(f'Swarm Plot of {feature} by Species')
    plt.show()
# Out:
# /home/agrima/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Bivariate Analysis
# ##### Exploring relationship between two variables

# %%
#scatter plots

pairs = [
    ('SepalLengthCm', 'SepalWidthCm'),
    ('SepalLengthCm', 'PetalLengthCm'),
    ('SepalLengthCm', 'PetalWidthCm'),
    ('SepalWidthCm', 'PetalLengthCm'),
    ('SepalWidthCm', 'PetalWidthCm'),
    ('PetalLengthCm', 'PetalWidthCm')
]


for i,j in pairs:
    plt.figure(figsize=(8,6))
    sb.scatterplot(data=df,x=i,y=j,hue="Species")
    plt.title('Scatter Plot of {i} vs {j}')
    plt.xlabel(i)
    plt.ylabel(j)
    plt.show()

# %% [markdown]
# ### Data Visualization

# %%
#historgram 
df.hist(bins=30,figsize=(20,15))
plt.show()

# %%
#box plot
plt.figure(figsize=(10,6))
sb.boxplot(df)
plt.show()

# %%
# bar charts
species_count=df['Species'].value_counts()
plt.figure(figsize=(8,6))
sb.barplot(x=species_count.index, y=species_count.values)
plt.title('Species Distribution in the Iris Dataset')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
#pie chart
plt.figure(figsize=(8,6))
plt.pie(species_count, labels=species_count.index, autopct='%1.1f%%', startangle=140,)
plt.title('Species Distribution in the Iris Dataset', color="white")
plt.show()

# %%
#pair plots 

sb.pairplot(df, hue='Species')
plt.show()

# %% [markdown]
# ### Correlation
#
# ##### It is a statistical phenomenon that occurs when independent variables are correlated with each other

# %%
#calculating correlation matrix

correlation_matrix=df.corr()
print(correlation_matrix)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
# Visualizing matrix using HeatMap
plt.figure(figsize=(8,6))
sb.heatmap(correlation_matrix,annot=True)
plt.show()

# %%
# Identify paris of feature with high collinearity

threshold=0.75
high_correlation=correlation_matrix[(correlation_matrix.abs()>threshold) & (correlation_matrix != 1.0)]
print(high_correlation.dropna(how="all").dropna(axis=1,how="all"))
# Out:
#                SepalLengthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm            NaN       0.871754      0.817954
# PetalLengthCm       0.871754            NaN      0.962757
# PetalWidthCm        0.817954       0.962757           NaN
